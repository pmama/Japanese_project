# %% [markdown]
# # mecab-python
#
# https://pypi.org/project/mecab-python3/

# %%
# !pip install mecab-python3
# Out:
# Collecting mecab-python3
#   Downloading mecab_python3-1.0.9-cp311-cp311-win_amd64.whl.metadata (6.3 kB)
# Downloading mecab_python3-1.0.9-cp311-cp311-win_amd64.whl (500 kB)
#    ---------------------------------------- 0.0/500.9 kB ? eta -:--:--
#    ---- ----------------------------------- 61.4/500.9 kB 1.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 286.7/500.9 kB 4.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 368.6/500.9 kB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 500.9/500.9 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: mecab-python3
# Successfully installed mecab-python3-1.0.9

# %%
import MeCab

text = "私はPythonが大好きです。"
mecab = MeCab.Tagger("-Owakati")
print(mecab.parse(text))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\MeCab\__init__.py:137, in Tagger.__init__(self, rawargs)
#     136 try:
# --> 137     super(Tagger, self).__init__(args)
#     138 except RuntimeError as ee:
#
# RuntimeError:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 4
#       1 import MeCab
#       3 text = "私はPythonが大好きです。"
# ----> 4 mecab = MeCab.Tagger("-Owakati")
#       5 print(mecab.parse(text))
#
# File ~\anaconda3\Lib\site-packages\MeCab\__init__.py:139, in Tagger.__init__(self, rawargs)
#     137     super(Tagger, self).__init__(args)
#     138 except RuntimeError as ee:
# --> 139     raise RuntimeError(error_info(rawargs)) from ee
#
# RuntimeError:
# ----------------------------------------------------------
#
# Failed initializing MeCab. Please see the README for possible solutions:
#
#     https://github.com/SamuraiT/mecab-python3#common-issues
#
# If you are still having trouble, please file an issue here, and include the
# ERROR DETAILS below:
#
#     https://github.com/SamuraiT/mecab-python3/issues
#
# issueを英語で書く必要はありません。
#
# ------------------- ERROR DETAILS ------------------------
# arguments: -Owakati
# default dictionary path: None
# [ifs] no such file or directory: c:\mecab\mecabrc
# ----------------------------------------------------------

# %% [markdown]
# # Janome

# %%
# !pip install janome
# Out:
# Collecting janome
#   Downloading Janome-0.5.0-py2.py3-none-any.whl.metadata (2.6 kB)
# Downloading Janome-0.5.0-py2.py3-none-any.whl (19.7 MB)
#    ---------------------------------------- 0.0/19.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/19.7 MB 1.3 MB/s eta 0:00:16
#     --------------------------------------- 0.2/19.7 MB 3.7 MB/s eta 0:00:06
#     --------------------------------------- 0.5/19.7 MB 4.2 MB/s eta 0:00:05
#    - -------------------------------------- 0.7/19.7 MB 4.2 MB/s eta 0:00:05
#    - -------------------------------------- 0.8/19.7 MB 4.4 MB/s eta 0:00:05
#    -- ------------------------------------- 1.4/19.7 MB 5.4 MB/s eta 0:00:04
#    --- ------------------------------------ 1.9/19.7 MB 6.3 MB/s eta 0:00:03
#    ---- ----------------------------------- 2.2/19.7 MB 6.5 MB/s eta 0:00:03
#    ----- ---------------------------------- 2.5/19.7 MB 6.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 2.9/19.7 MB 6.7 MB/s eta 0:00:03
#    ------- -------------------------------- 3.5/19.7 MB 6.9 MB/s eta 0:00:03
#    -------- ------------------------------- 4.0/19.7 MB 7.6 MB/s eta 0:00:03
#    --------- ------------------------------ 4.6/19.7 MB 7.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 5.1/19.7 MB 8.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 5.7/19.7 MB 8.4 MB/s eta 0:00:02
#    ------------ --------------------------- 6.2/19.7 MB 8.6 MB/s eta 0:00:02
#    ------------- -------------------------- 6.5/19.7 MB 8.6 MB/s eta 0:00:02
#    ------------- -------------------------- 6.5/19.7 MB 8.6 MB/s eta 0:00:02
#    ------------- -------------------------- 6.5/19.7 MB 8.6 MB/s eta 0:00:02
#    ------------- -------------------------- 6.5/19.7 MB 8.6 MB/s eta 0:00:02
#    ------------- -------------------------- 6.5/19.7 MB 8.6 MB/s eta 0:00:02
#    ------------- -------------------------- 6.6/19.7 MB 6.6 MB/s eta 0:00:02
#    -------------- ------------------------- 7.0/19.7 MB 6.7 MB/s eta 0:00:02
#    --------------- ------------------------ 7.5/19.7 MB 6.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 8.0/19.7 MB 6.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 8.5/19.7 MB 7.2 MB/s eta 0:00:02
#    ------------------ --------------------- 8.9/19.7 MB 7.2 MB/s eta 0:00:02
#    ------------------ --------------------- 9.3/19.7 MB 7.3 MB/s eta 0:00:02
#    ------------------- -------------------- 9.7/19.7 MB 7.4 MB/s eta 0:00:02
#    -------------------- ------------------- 10.2/19.7 MB 7.4 MB/s eta 0:00:02
#    --------------------- ------------------ 10.8/19.7 MB 8.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 11.3/19.7 MB 8.3 MB/s eta 0:00:02
#    ------------------------ --------------- 11.8/19.7 MB 8.4 MB/s eta 0:00:01
#    ------------------------- -------------- 12.3/19.7 MB 8.3 MB/s eta 0:00:01
#    ------------------------- -------------- 12.7/19.7 MB 8.5 MB/s eta 0:00:01
#    -------------------------- ------------- 13.0/19.7 MB 8.3 MB/s eta 0:00:01
#    --------------------------- ------------ 13.4/19.7 MB 8.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 13.9/19.7 MB 8.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 14.4/19.7 MB 8.2 MB/s eta 0:00:01
#    ------------------------------ --------- 14.8/19.7 MB 8.1 MB/s eta 0:00:01
#    ------------------------------- -------- 15.3/19.7 MB 8.2 MB/s eta 0:00:01
#    -------------------------------- ------- 15.7/19.7 MB 8.1 MB/s eta 0:00:01
#    --------------------------------- ------ 16.2/19.7 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 16.7/19.7 MB 10.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 17.3/19.7 MB 9.9 MB/s eta 0:00:01
#    ------------------------------------ --- 17.7/19.7 MB 10.1 MB/s eta 0:00:01
#    ------------------------------------- -- 18.3/19.7 MB 9.9 MB/s eta 0:00:01
#    -------------------------------------- - 18.7/19.7 MB 9.9 MB/s eta 0:00:01
#    -------------------------------------- - 19.1/19.7 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  19.6/19.7 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------  19.7/19.7 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 19.7/19.7 MB 9.8 MB/s eta 0:00:00
# Installing collected packages: janome
# Successfully installed janome-0.5.0

# %%
from janome.tokenizer import Tokenizer

tokenizer = Tokenizer()
text = "私はPythonが大好きです。"
tokens = tokenizer.tokenize(text, wakati=True)
print(" ".join(tokens))
# Out:
# 私 は Python が 大好き です 。

# %% [markdown]
# # Sudachi

# %%
# !pip install sudachipy
# !pip install sudachidict_core
# Out:
# Collecting sudachipy
#   Downloading SudachiPy-0.6.8-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Downloading SudachiPy-0.6.8-cp311-cp311-win_amd64.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    - -------------------------------------- 0.0/1.3 MB 1.9 MB/s eta 0:00:01
#    --------------- ------------------------ 0.5/1.3 MB 6.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 0.9/1.3 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 7.9 MB/s eta 0:00:00
# Installing collected packages: sudachipy
# Successfully installed sudachipy-0.6.8
# Collecting sudachidict_core
#   Downloading SudachiDict_core-20240409-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: SudachiPy<0.7,>=0.5 in c:\users\dilip\anaconda3\lib\site-packages (from sudachidict_core) (0.6.8)
# Downloading SudachiDict_core-20240409-py3-none-any.whl (72.0 MB)
#    ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#    ---------------------------------------- 0.2/72.0 MB 3.6 MB/s eta 0:00:21
#    ---------------------------------------- 0.7/72.0 MB 6.2 MB/s eta 0:00:12
#     --------------------------------------- 1.2/72.0 MB 7.4 MB/s eta 0:00:10
#     --------------------------------------- 1.6/72.0 MB 7.9 MB/s eta 0:00:09
#    - -------------------------------------- 2.2/72.0 MB 8.6 MB/s eta 0:00:09
#    - -------------------------------------- 2.6/72.0 MB 9.1 MB/s eta 0:00:08
#    - -------------------------------------- 3.1/72.0 MB 8.9 MB/s eta 0:00:08
#    -- ------------------------------------- 3.7/72.0 MB 9.3 MB/s eta 0:00:08
#    -- ------------------------------------- 4.2/72.0 MB 9.9 MB/s eta 0:00:07
#    -- ------------------------------------- 4.7/72.0 MB 10.0 MB/s eta 0:00:07
#    -- ------------------------------------- 5.3/72.0 MB 10.2 MB/s eta 0:00:07
#    --- ------------------------------------ 5.8/72.0 MB 10.3 MB/s eta 0:00:07
#    --- ------------------------------------ 6.4/72.0 MB 10.2 MB/s eta 0:00:07
#    --- ------------------------------------ 6.9/72.0 MB 10.6 MB/s eta 0:00:07
#    ---- ----------------------------------- 7.5/72.0 MB 10.6 MB/s eta 0:00:07
#    ---- ----------------------------------- 7.8/72.0 MB 10.6 MB/s eta 0:00:07
#    ---- ----------------------------------- 8.5/72.0 MB 10.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 9.1/72.0 MB 10.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 9.6/72.0 MB 10.6 MB/s eta 0:00:06
#    ----- ---------------------------------- 10.2/72.0 MB 10.9 MB/s eta 0:00:06
#    ------ --------------------------------- 10.8/72.0 MB 11.5 MB/s eta 0:00:06
#    ------ --------------------------------- 11.4/72.0 MB 11.5 MB/s eta 0:00:06
#    ------ --------------------------------- 12.0/72.0 MB 11.7 MB/s eta 0:00:06
#    ------ --------------------------------- 12.5/72.0 MB 11.7 MB/s eta 0:00:06
#    ------- -------------------------------- 13.1/72.0 MB 11.7 MB/s eta 0:00:06
#    ------- -------------------------------- 13.6/72.0 MB 11.7 MB/s eta 0:00:05
#    ------- -------------------------------- 14.2/72.0 MB 11.7 MB/s eta 0:00:05
#    -------- ------------------------------- 14.7/72.0 MB 11.7 MB/s eta 0:00:05
#    -------- ------------------------------- 15.3/72.0 MB 11.5 MB/s eta 0:00:05
#    -------- ------------------------------- 15.9/72.0 MB 11.7 MB/s eta 0:00:05
#    --------- ------------------------------ 16.2/72.0 MB 11.5 MB/s eta 0:00:05
#    --------- ------------------------------ 16.5/72.0 MB 11.1 MB/s eta 0:00:06
#    --------- ------------------------------ 17.1/72.0 MB 11.1 MB/s eta 0:00:05
#    --------- ------------------------------ 17.4/72.0 MB 10.9 MB/s eta 0:00:06
#    --------- ------------------------------ 17.7/72.0 MB 10.6 MB/s eta 0:00:06
#    ---------- ----------------------------- 18.1/72.0 MB 10.9 MB/s eta 0:00:05
#    ---------- ----------------------------- 18.5/72.0 MB 10.4 MB/s eta 0:00:06
#    ---------- ----------------------------- 19.1/72.0 MB 10.4 MB/s eta 0:00:06
#    ---------- ----------------------------- 19.6/72.0 MB 10.4 MB/s eta 0:00:06
#    ----------- ---------------------------- 20.2/72.0 MB 10.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 20.7/72.0 MB 10.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 21.3/72.0 MB 10.4 MB/s eta 0:00:05
#    ------------ --------------------------- 21.9/72.0 MB 10.4 MB/s eta 0:00:05
#    ------------ --------------------------- 22.4/72.0 MB 10.6 MB/s eta 0:00:05
#    ------------ --------------------------- 22.9/72.0 MB 10.4 MB/s eta 0:00:05
#    ------------- -------------------------- 23.4/72.0 MB 10.4 MB/s eta 0:00:05
#    ------------- -------------------------- 24.0/72.0 MB 10.6 MB/s eta 0:00:05
#    ------------- -------------------------- 24.5/72.0 MB 10.4 MB/s eta 0:00:05
#    ------------- -------------------------- 25.1/72.0 MB 10.4 MB/s eta 0:00:05
#    -------------- ------------------------- 25.6/72.0 MB 10.6 MB/s eta 0:00:05
#    -------------- ------------------------- 26.2/72.0 MB 10.4 MB/s eta 0:00:05
#    -------------- ------------------------- 26.7/72.0 MB 10.9 MB/s eta 0:00:05
#    --------------- ------------------------ 27.3/72.0 MB 10.9 MB/s eta 0:00:05
#    --------------- ------------------------ 27.9/72.0 MB 11.5 MB/s eta 0:00:04
#    --------------- ------------------------ 28.0/72.0 MB 11.3 MB/s eta 0:00:04
#    ---------------- ----------------------- 28.8/72.0 MB 11.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 29.3/72.0 MB 11.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 29.8/72.0 MB 11.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 30.4/72.0 MB 11.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 31.0/72.0 MB 11.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 31.5/72.0 MB 11.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 32.0/72.0 MB 11.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 32.4/72.0 MB 11.5 MB/s eta 0:00:04
#    ------------------ --------------------- 33.0/72.0 MB 11.5 MB/s eta 0:00:04
#    ------------------ --------------------- 33.5/72.0 MB 11.3 MB/s eta 0:00:04
#    ------------------ --------------------- 34.1/72.0 MB 11.3 MB/s eta 0:00:04
#    ------------------- -------------------- 34.7/72.0 MB 11.5 MB/s eta 0:00:04
#    ------------------- -------------------- 35.2/72.0 MB 11.3 MB/s eta 0:00:04
#    ------------------- -------------------- 35.8/72.0 MB 11.3 MB/s eta 0:00:04
#    -------------------- ------------------- 36.1/72.0 MB 11.5 MB/s eta 0:00:04
#    -------------------- ------------------- 36.8/72.0 MB 11.3 MB/s eta 0:00:04
#    -------------------- ------------------- 37.3/72.0 MB 11.3 MB/s eta 0:00:04
#    --------------------- ------------------ 37.9/72.0 MB 11.3 MB/s eta 0:00:04
#    --------------------- ------------------ 38.4/72.0 MB 11.7 MB/s eta 0:00:03
#    --------------------- ------------------ 38.9/72.0 MB 11.5 MB/s eta 0:00:03
#    --------------------- ------------------ 39.4/72.0 MB 11.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 40.1/72.0 MB 11.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 40.5/72.0 MB 11.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 41.1/72.0 MB 11.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 41.2/72.0 MB 11.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 41.8/72.0 MB 11.1 MB/s eta 0:00:03
#    ----------------------- ---------------- 42.2/72.0 MB 10.9 MB/s eta 0:00:03
#    ----------------------- ---------------- 42.7/72.0 MB 11.1 MB/s eta 0:00:03
#    ------------------------ --------------- 43.2/72.0 MB 10.9 MB/s eta 0:00:03
#    ------------------------ --------------- 43.8/72.0 MB 11.1 MB/s eta 0:00:03
#    ------------------------ --------------- 44.3/72.0 MB 10.7 MB/s eta 0:00:03
#    ------------------------ --------------- 44.8/72.0 MB 10.7 MB/s eta 0:00:03
#    ------------------------- -------------- 45.3/72.0 MB 10.7 MB/s eta 0:00:03
#    ------------------------- -------------- 45.8/72.0 MB 10.7 MB/s eta 0:00:03
#    ------------------------- -------------- 46.4/72.0 MB 10.9 MB/s eta 0:00:03
#    -------------------------- ------------- 46.9/72.0 MB 10.7 MB/s eta 0:00:03
#    -------------------------- ------------- 47.5/72.0 MB 10.7 MB/s eta 0:00:03
#    -------------------------- ------------- 48.1/72.0 MB 10.9 MB/s eta 0:00:03
#    -------------------------- ------------- 48.6/72.0 MB 10.9 MB/s eta 0:00:03
#    --------------------------- ------------ 49.2/72.0 MB 10.9 MB/s eta 0:00:03
#    --------------------------- ------------ 49.6/72.0 MB 10.9 MB/s eta 0:00:03
#    --------------------------- ------------ 50.2/72.0 MB 10.9 MB/s eta 0:00:03
#    ---------------------------- ----------- 50.7/72.0 MB 10.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 51.3/72.0 MB 10.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 51.8/72.0 MB 11.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 52.4/72.0 MB 11.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 52.9/72.0 MB 11.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 53.4/72.0 MB 11.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 54.0/72.0 MB 11.1 MB/s eta 0:00:02
#    ------------------------------ --------- 54.5/72.0 MB 11.5 MB/s eta 0:00:02
#    ------------------------------ --------- 55.0/72.0 MB 11.3 MB/s eta 0:00:02
#    ------------------------------ --------- 55.5/72.0 MB 11.5 MB/s eta 0:00:02
#    ------------------------------- -------- 56.1/72.0 MB 11.3 MB/s eta 0:00:02
#    ------------------------------- -------- 56.6/72.0 MB 11.3 MB/s eta 0:00:02
#    ------------------------------- -------- 57.2/72.0 MB 11.3 MB/s eta 0:00:02
#    -------------------------------- ------- 57.7/72.0 MB 11.3 MB/s eta 0:00:02
#    -------------------------------- ------- 58.3/72.0 MB 11.3 MB/s eta 0:00:02
#    -------------------------------- ------- 58.8/72.0 MB 11.3 MB/s eta 0:00:02
#    -------------------------------- ------- 59.4/72.0 MB 11.3 MB/s eta 0:00:02
#    --------------------------------- ------ 59.9/72.0 MB 11.5 MB/s eta 0:00:02
#    --------------------------------- ------ 60.5/72.0 MB 11.5 MB/s eta 0:00:02
#    --------------------------------- ------ 61.0/72.0 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 61.5/72.0 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 62.0/72.0 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 62.5/72.0 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 62.9/72.0 MB 11.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 63.5/72.0 MB 11.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 64.1/72.0 MB 11.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 64.5/72.0 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------ --- 65.1/72.0 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------ --- 65.3/72.0 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------ --- 66.0/72.0 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------ --- 66.4/72.0 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------- -- 66.9/72.0 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------- -- 67.4/72.0 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------- -- 67.9/72.0 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------- -- 68.4/72.0 MB 11.1 MB/s eta 0:00:01
#    -------------------------------------- - 68.8/72.0 MB 11.3 MB/s eta 0:00:01
#    -------------------------------------- - 69.2/72.0 MB 10.9 MB/s eta 0:00:01
#    -------------------------------------- - 69.7/72.0 MB 11.1 MB/s eta 0:00:01
#    -------------------------------------- - 70.2/72.0 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------  70.7/72.0 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------  71.1/72.0 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  71.7/72.0 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  72.0/72.0 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------  72.0/72.0 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------- 72.0/72.0 MB 10.1 MB/s eta 0:00:00
# Installing collected packages: sudachidict_core
# Successfully installed sudachidict_core-20240409

# %%
tokenizer_obj = dictionary.Dictionary().create()
mode = tokenizer.Tokenizer.SplitMode.C
text = "私はPythonが大好きです。"
tokens = [m.surface() for m in tokenizer_obj.tokenize(text, mode)]
print(" ".join(tokens))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 tokenizer_obj = dictionary.Dictionary().create()
#       2 mode = tokenizer.Tokenizer.SplitMode.C
#       3 text = "私はPythonが大好きです。"
#
# NameError: name 'dictionary' is not defined

# %%
from sudachipy import tokenizer
from sudachipy import dictionary

tokenizer_obj = dictionary.Dictionary().create()
mode = tokenizer.Tokenizer.SplitMode.C
text = "私はPythonが大好きです。"
tokens = [m.surface() for m in tokenizer_obj.tokenize(text, mode)]
print(" ".join(tokens))
# Out:
# 私 は Python が 大好き です 。
