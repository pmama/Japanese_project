# %% [markdown]
# <a href="https://colab.research.google.com/github/pmama/Japanese_project/blob/main/NLLB_200_text_Japanese_translation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  <div style="border-radius:0px; border:#3eb489 solid; padding: 15px; background-color: #0000FF; font-size:100%; text-align:center; color: white;">No Language Left Behind(NNLB) - 200 </div>
#
#
# No Language Left Behind-200 (NLLB-200), 200 languages within a single AI model, is a machine translation model primarily intended for research in machine translation, — especially for low-resource languages. It allows for single-sentence translation among 200 languages. NLLB-200 is a research model and has not been released for production deployment. NLLB-200 is trained on general domain text data and is not intended to be used with domain-specific texts, such as medical domain or legal domain.
#
# The model is not intended to be used for document translation. The model was trained with input lengths not exceeding 512 tokens, therefore translating longer sequences might result in quality degradation. NLLB-200 translations can not be used as certified translations.

# %% [markdown]
# # <div style="text-align: justify; font-family: 'Times Roman'; font-size:25px; color:blue"> Setting Environment: </div>

# %%
# !pip install transformers -q
# !pip install torch -q
# !pip install langchain_community langchain huggingface_hub["cli"] -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 53.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 12.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.6/973.6 kB 20.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.4/310.4 kB 20.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 kB 13.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 14.2 MB/s eta 0:00:00

# %% [markdown]
# # <div style="text-align: justify; font-family: 'Times Roman'; font-size:25px; color:blue">Translator Pipeline using HuggingFace Transformers</div>

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] ="****"

# %%
from transformers import pipeline
import torch
from langchain import HuggingFaceHub

# %%
pipe1 = pipeline(task = "translation", model = "facebook/nllb-200-distilled-600M", torch_dtype=torch.bfloat16)
pipe2 = pipeline(task = "translation", model = "facebook/nllb-200-distilled-1.3B", torch_dtype=torch.bfloat16)
pipe3 = pipeline(task = "translation", model = "facebook/nllb-200-3.3B",           torch_dtype=torch.bfloat16)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/3.55k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/808 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/5.48G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/3.55k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/808 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/90.0k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# pytorch_model-00001-of-00003.bin:   0%|          | 0.00/6.93G [00:00<?, ?B/s]
# pytorch_model-00002-of-00003.bin:   0%|          | 0.00/8.55G [00:00<?, ?B/s]
# pytorch_model-00003-of-00003.bin:   0%|          | 0.00/2.10G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/3.55k [00:00<?, ?B/s]

# %%
text = """
「おれの方が強い。「いいや、ぼくの方が強い。」北風と太陽の声が聞こえます。二人はどちらの力が強いかでケンカをしているようです。
「太陽が毎日元気だから、暑くてみんな困っているよ。おれが涼しい風を吹くと、みんな嬉しそうだ。おれの方ほうがみんなの役に立っているよ。」
「でも、ぼくがいないと、木や野菜は育だたないよ。冬は北風の吹く風が冷たくて、とても寒かった。みんなに出られなかったよね？
最近は暖かいから、みんな喜んでいるよ。」「いいや、あそこを見て。太陽が強つよく照らすから、川の水がもうすぐ無くなりそうだ。水がないと、
みんな生活できないよ。
"""

# %%
pipelines =[("NLLB200_600M", pipe1), ("NLLB200_1.3B", pipe2), ("NLLB200_3.3B", pipe3)]
def text_translation(source, target ):
    for model_name, pipe in pipelines:
        translated_text = pipe(text, src_lang= source,  tgt_lang= target)
        print(f"Model_name:, {model_name}")
        print('------------'*10)
        print(translated_text)

# %% [markdown]
# <span style="background-color:cyan;
#              color:blue;
#              font-size:20px;
#              text-align:center;
#              border-radius:20px;
#              font-weight:bold;
#              border:2px solid blacko;
#              padding:0px 20px;">Translating to English :
# </span>

# %%
text_translation("jpn_Jpan","eng_Latn")
# Out:
# Model_name:, NLLB200_600M
# ------------------------------------------------------------------------------------------------------------------------
# [{'translation_text': '"I\'m stronger". "Well, I\'m stronger". "I hear the north wind and the sun". Both of them seem to be fighting stronger and stronger. "The sun is good every day, and everyone is in trouble. I blow the cool wind, and everyone is happy. I\'m the one who helps everyone". "But without me, trees and vegetables won\'t grow.'}]
# Model_name:, NLLB200_1.3B
# ------------------------------------------------------------------------------------------------------------------------
# [{'translation_text': '"I am stronger". "No, I am stronger". You hear the north wind and the sun. They seem to be arguing about which is stronger. "The sun is bright every day, so everyone is in trouble. Everyone seems to be happy when I blow a cool wind. You are more useful to everyone". "But without me, trees and vegetables will not grow. In winter, the north wind blows cold and very cold. We could not all go out. Recently it is warm, so everyone is happy". "Well, look there. The sun shines so brightly, the river water seems to be almost gone. Without water, we can not all live.'}]
# Model_name:, NLLB200_3.3B
# ------------------------------------------------------------------------------------------------------------------------
# [{'translation_text': '"I am stronger". "Hello, I am stronger". I hear the voices of the north wind and the sun. It seems that they are fighting over which one is stronger. "The sun is bright every day, and everyone is in trouble because it is hot. When I blow a cool wind, everyone is happy. I am useful to everyone". "But without me, trees and vegetables will not grow. In winter, the north wind blows cold and very cold. Didn\'t everyone get out? Lately it\'s been warm, so everyone is happy". "Hello, look over there. The sun is shining brightly, so the water in the river will soon be gone. If there is no water, everyone can\'t live".'}]

# %% [markdown]
# <span style="background-color:cyan;
#              color:blue;
#              font-size:20px;
#              text-align:center;
#              border-radius:20px;
#              font-weight:bold;
#              border:2px solid blacko;
#              padding:0px 20px;">Translating to Hindi :
# </span>

# %%
text_translation("jpn_Jpan","hin_Deva")
# Out:
# Model_name:, NLLB200_600M
# ------------------------------------------------------------------------------------------------------------------------
# [{'translation_text': '"मैं मजबूत हूँ. " "ठीक है, मैं मजबूत हूँ. " उत्तर हवा और सूर्य की आवाजें सुनती हैं. दोनों ताकतवर और मजबूत दोनों लड़ रहे हैं. " "सूर्य हर दिन अच्छा है, और गर्म है, और सभी परेशान हैं. "जब मैं ठंडी हवा उड़ाती हूं, तो सभी खुश होते हैं. "मेरे पास सभी के लिए अच्छा है. " "लेकिन मेरे बिना, पेड़ और सब्जियां नहीं उगती हैं। सर्दियों में, उत्तर हवा ठंडी और बहुत ठंडी थी। सभी बाहर नहीं जा सकते थे, है ना? हाल ही में गर्म है, सभी खुश हैं। " "ठीक है, वहाँ देखो। सूरज बहुत मजबूत है, और अच्छी तरह से चमकता है, नदी का पानी जल्द ही खत्म हो जाएगा। पानी के बिना, हम सभी नहीं रह सकते।'}]
# Model_name:, NLLB200_1.3B
# ------------------------------------------------------------------------------------------------------------------------
# [{'translation_text': '"मैं मजबूत हूँ. " "नहीं, मैं मजबूत हूँ।" उत्तरी हवा और सूर्य की आवाजें सुनाई देती हैं। दोनों को लगता है कि वे किसकी ताकत मजबूत है, इस बारे में झगड़ रहे हैं। "सूरज हर दिन अच्छा है, इसलिए हर कोई गर्म है और मुसीबत में है। जब मैं ठंडी हवा उड़ाता हूं, तो हर कोई खुश लगता है। मैं सभी के लिए बेहतर हूं। " "लेकिन मेरे बिना, पेड़ और सब्जियां नहीं उगेंगी। सर्दियों में उत्तरी हवा बहती है और ठंड और बहुत ठंड थी। क्या आप नहीं जा सकते थे? हाल ही में यह गर्म है, इसलिए हर कोई खुश है। " " "ठीक है, वहाँ देखो। सूरज जोर से चमकता है, और नदी का पानी जल्द ही खत्म हो जाएगा। पानी के बिना, हम सभी नहीं रह सकते।'}]
# Model_name:, NLLB200_3.3B
# ------------------------------------------------------------------------------------------------------------------------
# [{'translation_text': '"मैं मजबूत हूँ" "मैं मजबूत हूँ" "मैं उत्तर की हवा और सूर्य की आवाज़ सुन सकता हूँ" ऐसा लगता है कि दोनों इस बात पर झगड़ रहे हैं कि कौन सा बल अधिक शक्तिशाली है "सूरज हर दिन अच्छा है, इसलिए सभी परेशान हैं क्योंकि यह गर्म है। जब मैं ठंडी हवाओं को उड़ाती हूं, तो सभी खुश होते हैं क्योंकि मैं सभी के लिए उपयोगी हूं" "लेकिन मेरे बिना, पेड़ और सब्जियां नहीं उगती हैं। सर्दियों में, उत्तर की हवाओं की हवाएं ठंडी और बहुत ठंडी होती थीं। क्या हम सभी बाहर नहीं जा सकते थे? हाल ही में यह गर्म है, इसलिए सभी खुश हैं। "ओह, ठीक है, वहाँ देखो। सूरज बहुत तेज चमकता है, इसलिए नदी का पानी जल्द ही खत्म हो जाएगा। पानी नहीं है, और सभी जीवित नहीं रह सकते हैं।'}]

# %% [markdown]
# <span style="background-color:cyan;
#              color:blue;
#              font-size:20px;
#              text-align:center;
#              border-radius:20px;
#              font-weight:bold;
#              border:2px solid blacko;
#              padding:0px 20px;"> Translating to Oriya :
# </span>

# %%
text_translation("jpn_Jpan","ory_Orya")
# Out:
# Model_name:, NLLB200_600M
# ------------------------------------------------------------------------------------------------------------------------
# [{'translation_text': '"ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ହଁ, ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ", "ମୁଁ ଅଧିକ ଶକ୍ତି'}]
# Model_name:, NLLB200_1.3B
# ------------------------------------------------------------------------------------------------------------------------
# [{'translation_text': '"ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ ।" "ନାଁ, ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ ।" ଉତ୍ତର ବାୟୁ ଏବଂ ସୂର୍ଯ୍ୟର ସ୍ୱର ଶୁଣାଯାଏ । ଦୁଇଜଣଙ୍କର ଶକ୍ତି କେଉଁ ଶକ୍ତିଶାଳୀ ବୋଲି ସେମାନେ ଝଗଡ଼ା କରୁଥିବା ପରି ମନେ ହୁଏ । "ସୂର୍ଯ୍ୟ ପ୍ରତିଦିନ ଉଜ୍ଜ୍ୱଳ, ତେଣୁ ସମସ୍ତେ ଅସୁବିଧାରେ ଅଛନ୍ତି । ମୁଁ ଯେତେବେଳେ ଥଣ୍ଡା ପବନ ବହାଇଥାଏ, ସମସ୍ତେ ଖୁସି ହୋଇଥାନ୍ତି । ମୁଁ ସମସ୍ତଙ୍କ ପାଇଁ ଅଧିକ ଉପଯୋଗୀ ।" "କିନ୍ତୁ ମୋ ବିନା ଗଛ ଏବଂ ପନିପରିବା ବଢ଼ିବ ନାହିଁ । ଶୀତଦିନେ ଉତ୍ତର ବାୟୁ ଶୀତଳ ଏବଂ ବହୁତ ଥଣ୍ଡା ହେଉଥିଲା । ସମସ୍ତେ ବାହାରକୁ ଯାଇପାରିବେ ନାହିଁ କି ? ନିକଟରେ ଗରମ ହୋଇଥିବାରୁ ସମସ୍ତେ ଖୁସି ହୋଇଥାନ୍ତି । " " "ନାଁ, ଦେଖ, ସେଠାକୁ ଦେଖ । ସୂର୍ଯ୍ୟ ଜୋର ଜୋର ଜବରଦସ୍ତ ଆଲୋକିତ ହୋଇଥିବାରୁ ନଦୀର ପାଣି ଶୀଘ୍ର ଶେଷ ହୋଇଯିବ । ପାଣି ନ ଥିଲେ, ସମସ୍ତେ ବଞ୍ଚିପାରିବେ ନାହିଁ ।'}]
# Model_name:, NLLB200_3.3B
# ------------------------------------------------------------------------------------------------------------------------
# [{'translation_text': '"ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ" "ମୁଁ ଅଧିକ ଶକ୍ତିଶାଳୀ" "ମୁଁ ଉତ୍ତର ପବନ ଏବଂ ସୂର୍ଯ୍ୟର ସ୍ୱର ଶୁଣିପାରୁଛି" "ସେମାନେ ପରସ୍ପର ମଧ୍ୟରେ ଲଢ଼େଇ କରୁଛନ୍ତି ଯେ କେଉଁ ଶକ୍ତି ଅଧିକ ଶକ୍ତିଶାଳୀ" "ସୂର୍ଯ୍ୟ ପ୍ରତିଦିନ ଭଲ, ଗରମ ଏବଂ ସମସ୍ତେ ଅସୁବିଧାରେ ଅଛନ୍ତି" "ଯେତେବେଳେ ମୁଁ ଥଣ୍ଡା ପବନ ବହେ, ସମସ୍ତେ ଖୁସି ହୁଅନ୍ତି, ମୁଁ ସମସ୍ତଙ୍କ ପାଇଁ ଉପଯୋଗୀ" "କିନ୍ତୁ ମୋ ବିନା ଗଛ ଏବଂ ପନିପରିବା ବଢିପାରିବ ନାହିଁ" "ଶୀତରେ ଉତ୍ତର ପବନ ବହେ, ଥଣ୍ଡା ଏବଂ ବହୁତ ଥଣ୍ଡା _ ସମସ୍ତେ ବାହାରକୁ ଯାଇପାରିଲେ ନାହିଁ କି? ଆଜିକାଲି ଗରମ ଅଛି, ସମସ୍ତେ ଖୁସି ଅଛନ୍ତି _" "ଓଃ, ଭଲ, ଦେଖ _ ସୂର୍ଯ୍ୟ ଶକ୍ତିଶାଳୀ, ତେଣୁ ନଦୀରେ ଜଳ ଶୀଘ୍ର ଶେଷ ହୋଇଯିବ _ ଜଳ ନାହିଁ, ସମସ୍ତେ ବଞ୍ଚି ପାରିବେ ନାହିଁ _"'}]

# %%
# References
- https://ai.meta.com/blog/nllb-200-high-quality-machine-translation/
- https://arxiv.org/abs/2207.04672
- https://github.com/facebookresearch/fairseq/tree/nllb
- https://github.com/facebookresearch/flores/blob/main/flores200/README.md#languages-in-flores-200
- https://www.wasabi-jpn.com/japanese-lessons/japanese-graded-readers-n4-the-north-wind-and-the-sun/
